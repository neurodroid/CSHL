# %%
import tdms
import imp
imp.reload(tdms)
import plot
import functions
import numpy as np
import matplotlib
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %% [markdown]
# # Cortical connectivity

# %%
data = tdms.read_tdms("/Volumes/NO NAME/Cortical Connectivity/LTP_Baseline-JM_67_20hz_vc_-70_ptx.tdms")
# data = tdms.read_tdms("/Volumes/DATA/data/tdms/CHSL-6.8.1701-8ICLAMPSPIKES.tdms")
# data = tdms.read_tdms("/Volumes/DATA/data/tdms/CHSL-6.8.1702iclamp-1.tdms")

# %%
tstim1 = 200.0
tstim2 = 235.0
tpulsestart = 700.0
pulsedur = 100.0

# %%
fig, axi, axv = plot.plot_traces(mode='vclamp')

dt = data['dt']
meansweep = np.mean([sweep for sweep in data['AI0'][1:]], axis=0)
meancommand = np.mean([sweep for sweep in data['AO1'][1:]], axis=0)
for sweep, command in zip(data['AI0'][1:], data['AO1'][1:]):
    times = np.arange(sweep.shape[0])*data['dt']
    axi.plot(times, sweep, alpha=0.1)
    axv.plot(times, command, alpha=0.1)
axi.plot(times, meansweep, '-k', alpha=0.7, lw=2)
axv.plot(times, meancommand, '-k', alpha=0.7, lw=2)
# Out:
# <img src="data:image/png;base64,..." width="640">
